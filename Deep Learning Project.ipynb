# %% [markdown]
# Hugging Face Difussion Models: https://github.com/huggingface/diffusers

# %% [markdown]
# # Steps
# 1. Clean and process data in this notebook - **Charles**
# 2. Train the base classification model (finetune resnet) - **Charles**
#
# Modify dataset:
#   3. Finetune Difussion model (follow this approach: https://colab.research.google.com/github/huggingface/notebooks/blob/main/diffusers/training_example.ipynb#scrollTo=e3eb5811-c10b-4dae-a58d-9583c42e7f57), play around with architecture and hyperparameters - **Shaan**, **Ethan**
#   4. Train a GAN/Balancing GAN on data (potentially follow this approach: https://github.com/IBM/BAGAN) - **Manas**
#   5. Resample Data(simple randomization, Monte Carlo, bootstrap, jackknife, etc.) - **Shaan**, **Ethan**, **Manas**
#
# Final Analysis:
# 6. Retrain models on modified datasets - **Charles**

# %% [markdown]
# Resources for loading datasets: https://huggingface.co/docs/datasets/image_load
