# %% [markdown]
# # 🤗 Training with Diffusers
#
# In recent months, it has become clear that diffusion models have taken the throne as the state-of-the-art generative models. Here, we will use Hugging Face's brand new [Diffusers](https://github.com/huggingface/diffusers) library to train a simple diffusion model.

# %% [markdown]
# ## Installing the dependencies
#
# This notebook leverages the [🤗 Datasets](https://huggingface.co/docs/datasets/index) library to load and preprocess image datasets and the [🤗 Accelerate](https://huggingface.co/docs/accelerate/index) library to simplify training on any number of GPUs, with features like automatic gradient accumulation and tensorboard logging. Let's install them here:

# %%
# !nvidia-smi
# Out:
# Sat Nov 26 04:06:06 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# %%capture
# !pip install diffusers[training]==0.5.1
# !pip install "ipywidgets>=7,<8"

# %% [markdown]
# As google colab has disabled external widgtes, we need to enable it explicitly. Run the following cell to be able to use `notebook_login` and `tqdm`:

# %%
#from google.colab import output
#output.enable_custom_widget_manager()

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd "/content/gdrive/MyDrive/DL Project/"
# Out:
# /content/gdrive/.shortcut-targets-by-id/1wi9vgavoChaiKzvd4yqdbBeMVY8Gujox/DL Project

# %% [markdown]
# If you're opening this notebook locally, make sure your environment has an install from the last version of those libraries.
#
# To be able to share your model with the community, there are a few more steps to follow.|
#
# First you have to store your authentication token from the Hugging Face website (sign up [here](https://huggingface.co/join) if you haven't already!) then execute the following cell and input your **write** token:

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.huggingface/token
# Login successful

# %% [markdown]
# Then you need to install Git-LFS to upload your model checkpoints:

# %%
# %%capture
# !sudo apt -qq install git-lfs
# !git config --global credential.helper store

# %%
# !unzip skewed_shrunk_bw.zip -d /content/data
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_1311.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_0966.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_0549.jpg
#   inflating: /content/data/skewed/data/Training/pituitary/Tr-pi_0761.jpg
#   inflating: /content/data/skewed/data/Training/pituitary/Tr-pi_0565.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_0290.jpg
#   inflating: /content/data/skewed/data/Training/pituitary/Tr-pi_0520.jpg
#   inflating: /content/data/skewed/data/Training/pituitary/Tr-pi_0231.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_0733.jpg
#   inflating: /content/data/skewed/data/Training/pituitary/Tr-pi_1146.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_0492.jpg
#   inflating: /content/data/skewed/data/Training/pituitary/Tr-pi_0718.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_0983.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_0580.jpg
#   inflating: /content/data/skewed/data/Training/pituitary/Tr-pi_0184.jpg
#   inflating: /content/data/skewed/data/Training/pituitary/Tr-pi_0616.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_0525.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_0038.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_0252.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_0822.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_0467.jpg
#   inflating: /content/data/skewed/data/Training/pituitary/Tr-pi_0722.jpg
#   inflating: /content/data/skewed/data/Training/pituitary/Tr-pi_0121.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_0484.jpg
#   inflating: /content/data/skewed/data/Training/pituitary/Tr-pi_1248.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_0314.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_0504.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_1294.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_1265.jpg
#   inflating: /content/data/skewed/data/Training/pituitary/Tr-pi_0311.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_1377.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_1371.jpg
#  extracting: /content/data/skewed/data/Training/pituitary/Tr-pi_1258.jpg
#   inflating: /content/data/skewed/data/Training/pituitary/Tr-piTr_0005.jpg
#   inflating: /content/data/skewed/data/Training/pituitary/Tr-pi_0826.jpg
#    creating: /content/data/skewed/data/Testing/
#    creating: /content/data/skewed/data/Testing/meningioma/
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0841.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1200.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0175.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0211.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0079.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0802.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1012.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0232.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0776.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0311.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0879.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1093.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0319.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0222.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0284.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0626.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0032.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0386.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0282.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1084.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1322.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0204.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1226.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0183.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0203.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0154.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0539.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0221.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0285.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0215.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0254.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0885.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0196.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1148.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0248.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0796.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1079.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1265.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0806.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0672.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0987.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0600.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0238.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0730.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1304.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0240.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1147.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0715.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0076.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0224.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0924.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0286.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1119.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0163.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0027.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0365.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0343.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0842.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1236.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0454.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1198.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0597.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0077.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0149.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0721.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0014.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0097.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0259.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0229.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0871.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0852.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1327.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0337.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0240.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0581.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1094.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0259.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0927.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0557.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0847.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0981.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1191.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1141.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0120.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0154.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0149.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0100.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0778.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0198.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0176.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0588.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1078.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0565.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0126.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0344.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0536.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0201.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0067.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0054.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0121.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1122.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0798.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1235.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0496.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0823.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0127.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0022.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1106.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-meTr_0003.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0057.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0413.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0999.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0168.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0018.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0907.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0096.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0304.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0048.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0114.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0393.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0066.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1056.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0558.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0818.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1083.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1329.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1285.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0046.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0011.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0621.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0241.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0436.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0918.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0723.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0172.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0603.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0218.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0390.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0257.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0115.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0826.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0970.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0916.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0218.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0248.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0606.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0711.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0487.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1234.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0123.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0896.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0614.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0286.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0055.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1029.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0106.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0697.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0586.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0955.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0011.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0114.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0065.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0269.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1049.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0531.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0808.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0244.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0272.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1167.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0189.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0230.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0725.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0756.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0813.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0132.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0294.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0734.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0241.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0084.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1293.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0252.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0019.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0079.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0071.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0476.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0433.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1209.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0670.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0640.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0679.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0544.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0147.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0158.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1270.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1195.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1057.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1202.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0058.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1142.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0308.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1267.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0128.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0942.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0033.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1212.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0659.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1203.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0018.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0029.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1316.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0848.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0812.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0137.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1160.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0192.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1134.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1032.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0554.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0426.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0305.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0868.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1296.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0809.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0316.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1307.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0873.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1146.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0506.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1172.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0658.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0283.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0091.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0991.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0830.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0265.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0106.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0144.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0317.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0757.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0867.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-meTr_0001.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0718.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0276.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0236.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1210.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1025.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0107.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1269.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0279.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0378.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0251.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1201.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0291.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0082.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0421.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0968.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0424.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0131.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0453.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0276.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0280.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0900.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0017.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0125.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0284.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0055.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1054.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0797.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0236.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1163.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0791.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1062.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0040.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1310.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0163.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0615.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0064.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0037.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0090.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0468.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0870.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0665.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0219.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0578.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0994.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1317.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0569.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0902.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0260.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1319.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0124.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0928.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0250.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1165.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0402.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0905.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0965.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0290.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0911.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0923.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0360.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0737.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0059.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0073.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0936.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0187.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0020.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0186.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0810.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0899.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0243.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1077.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0287.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0772.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0770.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1080.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1218.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0186.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0777.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0712.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0866.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0339.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0783.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0482.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0034.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0193.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0969.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0249.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0092.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0127.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0237.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0397.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0351.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0635.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0389.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0989.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0837.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0840.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0297.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0515.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0207.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1125.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1186.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0052.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0215.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1255.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1027.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0271.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1335.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-meTr_0005.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0025.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0996.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0355.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0657.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0816.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0795.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0348.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0190.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1207.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0752.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0478.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0184.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0890.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0116.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1223.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0682.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0761.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1177.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1252.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0566.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0255.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0384.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0749.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0143.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0102.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-meTr_0007.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0744.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0012.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0471.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0089.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0944.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0277.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0303.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0169.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0182.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1098.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1064.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0010.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0710.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0347.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0345.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1256.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0874.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0625.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1023.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0069.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0934.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0028.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0270.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0134.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0354.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0104.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1013.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0051.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1228.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0168.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0457.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0639.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1302.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0180.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1231.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0978.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0701.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1138.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0622.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0052.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1273.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0448.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0576.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0878.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0036.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0793.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0041.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0815.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0605.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0953.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0459.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1030.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0070.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1107.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1171.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0940.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0850.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0178.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0728.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0321.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0088.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0886.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0087.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0577.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1318.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0974.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1053.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1261.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0101.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0695.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0044.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0237.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-meTr_0006.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1048.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0604.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0522.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0702.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0278.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1071.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1052.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0179.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1000.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0108.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0641.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-meTr_0005.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0357.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0233.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0085.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0300.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0764.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0245.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0869.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1036.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0088.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0274.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0356.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0191.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1114.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0313.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0937.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0912.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0047.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0735.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0845.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1035.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0696.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0832.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1016.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1127.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0950.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0607.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0035.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0449.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0410.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1334.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0153.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0047.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0205.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0346.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0268.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0986.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0166.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0278.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0948.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1153.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0582.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0593.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1120.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0054.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0425.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0513.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0152.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0880.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0302.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0541.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0505.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0849.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0612.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-meTr_0004.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1136.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0184.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0200.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-meTr_0009.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0727.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1194.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0014.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0533.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0649.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0856.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0962.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0115.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0888.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0178.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0123.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0016.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0957.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0835.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0161.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0652.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0984.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0446.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0222.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0069.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0213.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0352.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0805.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0497.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0767.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0971.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0949.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0434.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0645.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0534.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0883.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0829.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0022.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0341.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0192.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0993.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0376.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0395.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1151.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1227.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0135.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0972.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1124.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0225.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0575.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0790.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0056.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0053.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0203.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0502.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0359.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0700.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0651.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1254.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1220.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0753.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0290.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0239.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0472.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0794.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_1018.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1121.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0380.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1011.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1221.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0409.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0363.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0239.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1305.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0185.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0100.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Te-me_0262.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0491.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0265.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0630.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0427.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0089.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Te-me_0275.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1051.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_0784.jpg
#  extracting: /content/data/skewed/data/Testing/meningioma/Tr-me_0518.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1277.jpg
#   inflating: /content/data/skewed/data/Testing/meningioma/Tr-me_1034.jpg
# ...
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0303.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0013.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1139.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0205.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0821.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1030.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1150.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0275.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1402.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Te-pi_0199.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0310.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0621.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Te-pi_0232.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1259.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0920.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0962.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Te-pi_0085.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Te-pi_0059.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1088.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0291.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1012.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0324.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0229.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0224.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1234.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1374.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1268.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0013.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0807.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0779.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0212.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1076.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0281.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0906.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0771.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1381.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0010.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1436.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1365.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0595.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0796.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0299.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1316.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0393.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0254.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0856.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0641.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0451.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1454.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0292.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0745.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1442.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0727.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0142.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1065.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0339.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Te-pi_0241.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0274.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0117.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0092.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0725.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1102.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0068.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1164.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0149.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1451.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0481.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0047.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1136.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1170.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0161.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0488.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1140.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0762.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0499.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0014.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0242.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1410.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0479.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0666.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1266.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0696.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1183.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0189.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0232.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Te-pi_0037.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0602.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0167.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0096.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1336.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Te-pi_0128.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0511.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0729.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1345.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0838.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0681.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0774.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1274.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1249.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Te-pi_0295.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0627.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0281.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0057.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0172.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Te-pi_0141.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-piTr_0003.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0509.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Te-pi_0134.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1276.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Te-pi_0127.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0994.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0840.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0381.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0505.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1439.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0147.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0317.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1422.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Te-pi_0094.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0035.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Te-pi_0024.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0211.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0127.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0052.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0101.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1315.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0483.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1290.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0719.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0583.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0116.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0218.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0460.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0692.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0756.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0255.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1213.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0256.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0188.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-piTr_0001.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1321.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1215.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0249.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1445.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0276.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0146.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1151.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0490.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0468.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0663.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1032.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1262.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1358.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0044.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0514.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0133.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0286.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1181.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0592.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1131.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0704.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0624.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0782.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0267.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0169.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0748.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0839.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0563.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1227.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0570.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0713.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0098.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1084.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0130.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0648.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0152.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0461.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0534.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0991.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1311.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0549.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0761.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0565.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0290.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0520.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0231.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0733.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_1146.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0492.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0056.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0718.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0983.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0580.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0184.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Te-pi_0112.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0616.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0038.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0252.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0822.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0467.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0722.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Te-pi_0137.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0121.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0484.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1248.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0314.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1294.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1265.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-pi_0311.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0019.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1377.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1371.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Te-pi_0049.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_1258.jpg
#   inflating: /content/data/skewed/data/Testing/pituitary/Tr-piTr_0005.jpg
#  extracting: /content/data/skewed/data/Testing/pituitary/Tr-pi_0826.jpg

# %%
cd /content
# Out:
# /content

# %%
class_name = 'pituitary'

# %% [markdown]
# ## Config
#
# For convenience, we define a configuration grouping all the training hyperparameters. This would be similar to the arguments used for a [training script](https://github.com/huggingface/diffusers/tree/main/examples).
# Here we choose reasonable defaults for hyperparameters like `num_epochs`, `learning_rate`, `lr_warmup_steps`, but feel free to adjust them if you train on your own dataset. For example, `num_epochs` can be increased to 100 for better visual quality.

# %%
from dataclasses import dataclass

@dataclass
class TrainingConfig:
    image_size = 128  # the generated image resolution
    train_batch_size = 16
    eval_batch_size = 16  # how many images to sample during evaluation
    num_epochs = 50
    gradient_accumulation_steps = 1
    learning_rate = 1e-4
    lr_warmup_steps = 500
    save_image_epochs = 10
    save_model_epochs = 10
    output_dir = f'cancer_diffusion_model_{class_name}_new'
    mixed_precision = 'fp16'  # `no` for float32, `fp16` for automatic mixed precision
    push_to_hub = True  # whether to upload the saved model to the HF Hub
    hub_private_repo = False  
    overwrite_output_dir = True  # overwrite the old model when re-running the notebook
    seed = 0

config = TrainingConfig()

# %%
#img_dir = os.path.join("/content/drive/My Drive/DL Project/data/skewed/Training/", "pituitary")

# %%
#print(os.path.join(img_dir, 'Tr-pi_' + '0000' + '.jpg'))

# %% [markdown]
# ## Loading the dataset
#
# We will use the [🤗 Datasets](https://github.com/huggingface/datasets) library to download our image dataset.
#
# In this case, the [Butterflies dataset](https://huggingface.co/datasets/huggan/smithsonian_butterflies_subset) is hosted remotely, but you can load a local [ImageFolder](https://huggingface.co/docs/datasets/v2.0.0/en/image_process#imagefolder) as shown in the commets below.

# %%
import os

root_dir = "/content/data/skewed/data/Training/"
dir_types = ['pituitary', 'glioma', 'notumor', 'meningioma']
files = {}
for dir_type in dir_types:  
  files[dir_type] = []
for dir_type in dir_types:
  files[dir_type] = [os.path.join(root_dir, dir_type, filename) for filename in os.listdir(os.path.join(root_dir, dir_type))]

# %%
from datasets import Dataset, Image
tumor_dataset = Dataset.from_dict({"image": files[class_name]}).cast_column("image", Image())
config.dataset_name = class_name

# %% [markdown]
# The dataset contains several extra `features` (columns), but the one that we're interested in is `image`:

# %% [markdown]
# Since the [`Image`](https://huggingface.co/docs/datasets/image_process#image-datasets) feature loads the images with PIL, we can easily look at a few examples:

# %%
print(tumor_dataset[0])
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=L size=128x128 at 0x7EFFD8689950>}

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 4, figsize=(16, 4))
for i, image in enumerate(tumor_dataset[:4]["image"]):
    axs[i].imshow(image)
    axs[i].set_axis_off()
fig.show()

# %%
# !nvidia-smi
# Out:
# Sat Nov 26 04:06:40 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# The images in the dataset are all different, so we need to preprocess them first:
# * `Resize` makes the images conform to a square resolution of `config.image_size`
# * `RandomHorizontalFlip` augments the dataset by randomly mirroring the images.
# * `Normalize` is important to rescale the pixel values into a `[-1, 1]` range (which our model will expect).

# %%
from torchvision import transforms

preprocess = transforms.Compose(
    [
        transforms.Resize((config.image_size, config.image_size)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5]),
    ]
)

# %%
tumor_dataset[:4]
# Out:
# {'image': [<PIL.JpegImagePlugin.JpegImageFile image mode=L size=128x128 at 0x7EFFD6EB62D0>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=L size=128x128 at 0x7EFFD6F140D0>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=L size=128x128 at 0x7EFFE0B95B50>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=L size=128x128 at 0x7EFFE0B950D0>]}

# %% [markdown]
# 🤗 Datasets offer a handy `set_transform()` method to apply the image transformations on the fly during training:

# %%
def transform(examples):
    images = [preprocess(image.convert("RGB")) for image in examples["image"]]
    return {"image": images}

tumor_dataset.set_transform(transform)

# %% [markdown]
# Let's see what they look like now

# %%
fig, axs = plt.subplots(1, 4, figsize=(16, 4))
for i, image in enumerate(tumor_dataset[4:8]["image"]):
    axs[i].imshow(image.permute(1, 2, 0).numpy() / 2 + 0.5)
    axs[i].set_axis_off()
fig.show()

# %% [markdown]
# Now that all our images have the same size and are converted to tensors, we can create the dataloader we will use for training.

# %%
import torch

train_dataloader = torch.utils.data.DataLoader(tumor_dataset, batch_size=config.train_batch_size, shuffle=True)

# %% [markdown]
# ## Defining the diffusion model
#
# Here we set up our diffusion model. Diffusion models are neural networks that are trained to predict slightly less noisy images from a noisy input. At inference, they can be used to iteratively transform a random noise to generate an image:
#
# <p align="center">
#     <img src="https://user-images.githubusercontent.com/10695622/174349667-04e9e485-793b-429a-affe-096e8199ad5b.png" width="800"/>
#     <br>
#     <em> Figure from DDPM paper (https://arxiv.org/abs/2006.11239). </em>
# <p>
#
# Don't worry too much about the math if you're not familiar with it, the import part to remember is that our model corresponds to the arrow $p_{\theta}(x_{t-1}|x_{t})$ (which is a fancy way of saying: predict a slightly less noisy image).
#
# The interesting part is that it's really easy to add some noise to an image, so the training can happen in a semi-supervised fashion as follows:
# 1. Take an image from the training set.
# 2. Apply to it some random noise $t$ times (this will give the $x_{t-1}$ and the $x_{t}$ in the figure above).
# 3. Give this noisy image to the model along with the value of $t$.
# 4. Compute a loss from the output of the model and the noised image $x_{t-1}$.
#
# Then we can apply gradient descent and repeat this process multiple times.

# %% [markdown]
# Most diffusion models use architectures that are some variant of a [U-net](https://arxiv.org/abs/1505.04597) and that's what we'll use here.
#
# ![](https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/unet-model.png)
#
# In a nutshell:
# - the model has the input image go through several blocks of ResNet layers which halves the image size by 2
# - then through the same number of blocks that upsample it again.
# - there are skip connections linking the features on the downample path to the corresponsding layers in the upsample path.
#
# A key feature of this model is that it predicts images of the same size as the input, which is exactly what we need here.
#
# Diffusers provides us a handy `UNet2DModel` class which creates the desired architecture in PyTorch.
#
# Let's create a U-net for our desired image size.
# Note that `down_block_types` correspond to the downsampling blocks (green on the diagram above), and `up_block_types` are the upsampling blocks (red on the diagram):

# %%
from diffusers import UNet2DModel


model = UNet2DModel(
    sample_size=config.image_size,  # the target image resolution
    in_channels=3,  # the number of input channels, 3 for RGB images
    out_channels=3,  # the number of output channels
    layers_per_block=2,  # how many ResNet layers to use per UNet block
    block_out_channels=(128, 128, 256, 256, 512, 512),  # the number of output channes for each UNet block
    down_block_types=( 
        "DownBlock2D",  # a regular ResNet downsampling block
        "DownBlock2D", 
        "DownBlock2D", 
        "DownBlock2D", 
        "AttnDownBlock2D",  # a ResNet downsampling block with spatial self-attention
        "DownBlock2D",
    ), 
    up_block_types=(
        "UpBlock2D",  # a regular ResNet upsampling block
        "AttnUpBlock2D",  # a ResNet upsampling block with spatial self-attention
        "UpBlock2D", 
        "UpBlock2D", 
        "UpBlock2D", 
        "UpBlock2D"  
      ),
)

# %% [markdown]
# Let's get a sample image from our dataset and pass it into our model. We just need to add a batch dimension:

# %%
#sample_image = pituitary_dataset[0]['image'].unsqueeze(0)
#print('Input shape:', sample_image.shape)

# %% [markdown]
# And let's check the output is a tensor of the same exact shape:

# %%
#print('Output shape:', model(sample_image, timestep=0).sample.shape)

# %% [markdown]
# Great!
#
# Note that our model takes in the (noisy) image and also the current time-step (as we saw before in the training overview). That time-step information is converted for the model using a sinusoidal positional embedding, similar to what Transformer models often do.
#
# Now that we have our model, we just need an object to *add noise to an image*. This is done by the **schedulers** in the `diffusers` library.

# %% [markdown]
# ## Defining the noise scheduler
#
# Depending on the diffusion algorithm you want to use, the way images are noised is slightly different. That's why 🤗 Diffusers contains different scheduler classes which each define the algorithm-specific diffusion steps. Here we are going to use the `DDPMScheduler` which corresponds to the training denoising and training algorithm proposed in [Denoising Diffusion Probabilistic Models](https://arxiv.org/abs/2006.11239).

# %%
from diffusers import DDPMScheduler

noise_scheduler = DDPMScheduler(num_train_timesteps=1000)

# %% [markdown]
# Let's see how this noise scheduler works: it takes a batch of images from the trainng set (here we will reuse the batch of one image `sample_image` form before), a batch of random noise of the same shape and the timesteps for each image (which correspond to the number of times we want to apply noise to each image):

# %%
import torch
from PIL import Image

#noise = torch.randn(sample_image.shape)
#timesteps = torch.LongTensor([50])
#noisy_image = noise_scheduler.add_noise(sample_image, noise, timesteps)

#Image.fromarray(((noisy_image.permute(0, 2, 3, 1) + 1.0) * 127.5).type(torch.uint8).numpy()[0])

# %% [markdown]
# In the DDPM algorithm, the training objective of the model is then to be able to predict the noise we used in `noise_scheduler.add_noise`, so the loss at this step would be:

# %%
import torch.nn.functional as F

#noise_pred = model(noisy_image, timesteps).sample
#loss = F.mse_loss(noise_pred, noise)

# %% [markdown]
# ## Setting up training
#
# We have all we need to be able to train our model! Let's use a standard AdamW optimizer:

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=config.learning_rate)

# %% [markdown]
#  And a cosine learning rate schedule:

# %%
from diffusers.optimization import get_cosine_schedule_with_warmup

lr_scheduler = get_cosine_schedule_with_warmup(
    optimizer=optimizer,
    num_warmup_steps=config.lr_warmup_steps,
    num_training_steps=(len(train_dataloader) * config.num_epochs),
)

# %% [markdown]
# To evaluate our model, we use the `DDPMPipeline` which is an easy way to perform end-to-end inference (see this notebook [TODO link] for more detail). We will use this pipeline to generate a batch of sample images and save it as a grid to the disk.

# %%
from diffusers import DDPMPipeline

import math

def make_grid(images, rows, cols):
    w, h = images[0].size
    grid = Image.new('RGB', size=(cols*w, rows*h))
    for i, image in enumerate(images):
        grid.paste(image, box=(i%cols*w, i//cols*h))
    return grid

def evaluate(config, epoch, pipeline):
    # Sample some images from random noise (this is the backward diffusion process).
    # The default pipeline output type is `List[PIL.Image]`
    images = pipeline(
        batch_size = config.eval_batch_size, 
        generator=torch.manual_seed(config.seed),
    ).images

    # Make a grid out of the images
    image_grid = make_grid(images, rows=4, cols=4)

    # Save the images
    test_dir = os.path.join(config.output_dir, "samples")
    os.makedirs(test_dir, exist_ok=True)
    image_grid.save(f"{test_dir}/{epoch:04d}.png")

def get_images(config, epoch, batch, pipeline):
    # Sample some images from random noise (this is the backward diffusion process).
    # The default pipeline output type is `List[PIL.Image]`
    images = pipeline(
        batch_size = 16, 
        generator=torch.manual_seed(batch),
    ).images

    # Make a grid out of the images
    #image_grid = make_grid(images, rows=4, cols=4)

    # Save the images
    test_dir = os.path.join(config.output_dir, "samples")
    os.makedirs(test_dir, exist_ok=True)
    for i,img in enumerate(images):
      img.save(f"{test_dir}/{epoch:04d}_{batch}_{i}.png")

# %%
model.cuda()
# Out:
# UNet2DModel(
#   (conv_in): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (time_proj): Timesteps()
#   (time_embedding): TimestepEmbedding(
#     (linear_1): Linear(in_features=128, out_features=512, bias=True)
#     (act): SiLU()
#     (linear_2): Linear(in_features=512, out_features=512, bias=True)
#   )
#   (down_blocks): ModuleList(
#     (0): DownBlock2D(
#       (resnets): ModuleList(
#         (0): ResnetBlock2D(
#           (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=128, bias=True)
#           (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#         (1): ResnetBlock2D(
#           (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=128, bias=True)
#           (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#       )
#       (downsamplers): ModuleList(
#         (0): Downsample2D(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (1): DownBlock2D(
#       (resnets): ModuleList(
#         (0): ResnetBlock2D(
#           (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=128, bias=True)
#           (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#         (1): ResnetBlock2D(
#           (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=128, bias=True)
#           (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#       )
#       (downsamplers): ModuleList(
#         (0): Downsample2D(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (2): DownBlock2D(
#       (resnets): ModuleList(
#         (0): ResnetBlock2D(
#           (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#           (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=256, bias=True)
#           (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): ResnetBlock2D(
#           (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=256, bias=True)
#           (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#       )
#       (downsamplers): ModuleList(
#         (0): Downsample2D(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (3): DownBlock2D(
#       (resnets): ModuleList(
#         (0): ResnetBlock2D(
#           (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=256, bias=True)
#           (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#         (1): ResnetBlock2D(
#           (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=256, bias=True)
#           (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#       )
#       (downsamplers): ModuleList(
#         (0): Downsample2D(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (4): AttnDownBlock2D(
#       (attentions): ModuleList(
#         (0): AttentionBlock(
#           (group_norm): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (query): Linear(in_features=512, out_features=512, bias=True)
#           (key): Linear(in_features=512, out_features=512, bias=True)
#           (value): Linear(in_features=512, out_features=512, bias=True)
#           (proj_attn): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (1): AttentionBlock(
#           (group_norm): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (query): Linear(in_features=512, out_features=512, bias=True)
#           (key): Linear(in_features=512, out_features=512, bias=True)
#           (value): Linear(in_features=512, out_features=512, bias=True)
#           (proj_attn): Linear(in_features=512, out_features=512, bias=True)
#         )
#       )
#       (resnets): ModuleList(
#         (0): ResnetBlock2D(
#           (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=512, bias=True)
#           (norm2): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): ResnetBlock2D(
#           (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=512, bias=True)
#           (norm2): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#       )
#       (downsamplers): ModuleList(
#         (0): Downsample2D(
#           (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (5): DownBlock2D(
#       (resnets): ModuleList(
#         (0): ResnetBlock2D(
#           (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=512, bias=True)
#           (norm2): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#         (1): ResnetBlock2D(
#           (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=512, bias=True)
#           (norm2): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#       )
#     )
#   )
#   (up_blocks): ModuleList(
#     (0): UpBlock2D(
#       (resnets): ModuleList(
#         (0): ResnetBlock2D(
#           (norm1): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           (conv1): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=512, bias=True)
#           (norm2): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): ResnetBlock2D(
#           (norm1): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           (conv1): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=512, bias=True)
#           (norm2): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): ResnetBlock2D(
#           (norm1): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           (conv1): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=512, bias=True)
#           (norm2): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (upsamplers): ModuleList(
#         (0): Upsample2D(
#           (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#     )
#     (1): AttnUpBlock2D(
#       (attentions): ModuleList(
#         (0): AttentionBlock(
#           (group_norm): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (query): Linear(in_features=512, out_features=512, bias=True)
#           (key): Linear(in_features=512, out_features=512, bias=True)
#           (value): Linear(in_features=512, out_features=512, bias=True)
#           (proj_attn): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (1): AttentionBlock(
#           (group_norm): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (query): Linear(in_features=512, out_features=512, bias=True)
#           (key): Linear(in_features=512, out_features=512, bias=True)
#           (value): Linear(in_features=512, out_features=512, bias=True)
#           (proj_attn): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (2): AttentionBlock(
#           (group_norm): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (query): Linear(in_features=512, out_features=512, bias=True)
#           (key): Linear(in_features=512, out_features=512, bias=True)
#           (value): Linear(in_features=512, out_features=512, bias=True)
#           (proj_attn): Linear(in_features=512, out_features=512, bias=True)
#         )
#       )
#       (resnets): ModuleList(
#         (0): ResnetBlock2D(
#           (norm1): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           (conv1): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=512, bias=True)
#           (norm2): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): ResnetBlock2D(
#           (norm1): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           (conv1): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=512, bias=True)
#           (norm2): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): ResnetBlock2D(
#           (norm1): GroupNorm(32, 768, eps=1e-05, affine=True)
#           (conv1): Conv2d(768, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=512, bias=True)
#           (norm2): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (upsamplers): ModuleList(
#         (0): Upsample2D(
#           (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#     )
#     (2): UpBlock2D(
#       (resnets): ModuleList(
#         (0): ResnetBlock2D(
#           (norm1): GroupNorm(32, 768, eps=1e-05, affine=True)
#           (conv1): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=256, bias=True)
#           (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): ResnetBlock2D(
#           (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=256, bias=True)
#           (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): ResnetBlock2D(
#           (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=256, bias=True)
#           (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (upsamplers): ModuleList(
#         (0): Upsample2D(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#     )
#     (3): UpBlock2D(
#       (resnets): ModuleList(
#         (0): ResnetBlock2D(
#           (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=256, bias=True)
#           (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): ResnetBlock2D(
#           (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#           (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=256, bias=True)
#           (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): ResnetBlock2D(
#           (norm1): GroupNorm(32, 384, eps=1e-05, affine=True)
#           (conv1): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=256, bias=True)
#           (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (upsamplers): ModuleList(
#         (0): Upsample2D(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#     )
#     (4): UpBlock2D(
#       (resnets): ModuleList(
#         (0): ResnetBlock2D(
#           (norm1): GroupNorm(32, 384, eps=1e-05, affine=True)
#           (conv1): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=128, bias=True)
#           (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): ResnetBlock2D(
#           (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=128, bias=True)
#           (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): ResnetBlock2D(
#           (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=128, bias=True)
#           (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (upsamplers): ModuleList(
#         (0): Upsample2D(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#     )
#     (5): UpBlock2D(
#       (resnets): ModuleList(
#         (0): ResnetBlock2D(
#           (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=128, bias=True)
#           (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): ResnetBlock2D(
#           (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=128, bias=True)
#           (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): ResnetBlock2D(
#           (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=512, out_features=128, bias=True)
#           (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#   )
#   (mid_block): UNetMidBlock2D(
#     (attentions): ModuleList(
#       (0): AttentionBlock(
#         (group_norm): GroupNorm(32, 512, eps=1e-05, affine=True)
#         (query): Linear(in_features=512, out_features=512, bias=True)
#         (key): Linear(in_features=512, out_features=512, bias=True)
#         (value): Linear(in_features=512, out_features=512, bias=True)
#         (proj_attn): Linear(in_features=512, out_features=512, bias=True)
#       )
#     )
#     (resnets): ModuleList(
#       (0): ResnetBlock2D(
#         (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (time_emb_proj): Linear(in_features=512, out_features=512, bias=True)
#         (norm2): GroupNorm(32, 512, eps=1e-05, affine=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (nonlinearity): SiLU()
#       )
#       (1): ResnetBlock2D(
#         (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (time_emb_proj): Linear(in_features=512, out_features=512, bias=True)
#         (norm2): GroupNorm(32, 512, eps=1e-05, affine=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (nonlinearity): SiLU()
#       )
#     )
#   )
#   (conv_norm_out): GroupNorm(32, 128, eps=1e-05, affine=True)
#   (conv_act): SiLU()
#   (conv_out): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %% [markdown]
# With this in end, we can group all together and write our training function. This just wraps the training step we saw in the previous section in a loop, using Accelerate for easy TensorBoard logging, gradient accumulation, mixed precision training and multi-GPUs or TPU training.

# %%
from accelerate import Accelerator
from diffusers.hub_utils import init_git_repo, push_to_hub

from tqdm.auto import tqdm
import os

def train_loop(config, model, noise_scheduler, optimizer, train_dataloader, lr_scheduler):
    # Initialize accelerator and tensorboard logging
    accelerator = Accelerator(
        mixed_precision=config.mixed_precision,
        gradient_accumulation_steps=config.gradient_accumulation_steps, 
        log_with="tensorboard",
        logging_dir=os.path.join(config.output_dir, "logs")
    )
    if accelerator.is_main_process:
        if config.push_to_hub:
            repo = init_git_repo(config, at_init=True)
        accelerator.init_trackers("train_example")
    
    # Prepare everything
    # There is no specific order to remember, you just need to unpack the 
    # objects in the same order you gave them to the prepare method.
    model, optimizer, train_dataloader, lr_scheduler = accelerator.prepare(
        model, optimizer, train_dataloader, lr_scheduler
    )
    
    global_step = 0

    # Now you train the model
    for epoch in range(config.num_epochs):
        progress_bar = tqdm(total=len(train_dataloader), disable=not accelerator.is_local_main_process)
        progress_bar.set_description(f"Epoch {epoch}")

        for step, batch in enumerate(train_dataloader):
            clean_images = batch['image']
            # Sample noise to add to the images
            noise = torch.randn(clean_images.shape).to(clean_images.device)
            bs = clean_images.shape[0]

            # Sample a random timestep for each image
            timesteps = torch.randint(0, noise_scheduler.num_train_timesteps, (bs,), device=clean_images.device).long()

            # Add noise to the clean images according to the noise magnitude at each timestep
            # (this is the forward diffusion process)
            noisy_images = noise_scheduler.add_noise(clean_images, noise, timesteps)
            
            with accelerator.accumulate(model):
                # Predict the noise residual
                noise_pred = model(noisy_images, timesteps, return_dict=False)[0]
                loss = F.mse_loss(noise_pred, noise)
                accelerator.backward(loss)

                accelerator.clip_grad_norm_(model.parameters(), 1.0)
                optimizer.step()
                lr_scheduler.step()
                optimizer.zero_grad()
            
            progress_bar.update(1)
            logs = {"loss": loss.detach().item(), "lr": lr_scheduler.get_last_lr()[0], "step": global_step}
            progress_bar.set_postfix(**logs)
            accelerator.log(logs, step=global_step)
            global_step += 1

        # After each epoch you optionally sample some demo images with evaluate() and save the model
        if accelerator.is_main_process:
            pipeline = DDPMPipeline(unet=accelerator.unwrap_model(model), scheduler=noise_scheduler)
            if (epoch + 1) % config.save_image_epochs == 0 or epoch == config.num_epochs - 1:
                get_images(config, epoch, 1, pipeline)
            if (epoch + 1) % config.save_model_epochs == 0 or epoch == config.num_epochs - 1:
                if config.push_to_hub:
                    push_to_hub(config, pipeline, repo, commit_message=f"Epoch {epoch}", blocking=True)
                else:
                    pipeline.save_pretrained(config.output_dir)

# %% [markdown]
# ## Let's train!
#
# Let's launch the training (including multi-GPU training) from the notebook using Accelerate's `notebook_launcher` function:

# %%
from accelerate import notebook_launcher
args = (config, model, noise_scheduler, optimizer, train_dataloader, lr_scheduler)
notebook_launcher(train_loop, args, num_processes=1)
# Out:
# Launching training on one GPU.
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/repository.py:729: FutureWarning: Creating a repository through 'clone_from' is deprecated and will be removed in v0.12. Please create the repository first using `create_repo(..., exists_ok=True)`.
#   FutureWarning,
# Cloning https://huggingface.co/emendes3/cancer_diffusion_model_pituitary_new into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/emendes3/cancer_diffusion_model_pituitary_new into local empty directory.
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Adding files tracked by Git LFS: ['samples/0009_1_0.png', 'samples/0009_1_1.png', 'samples/0009_1_10.png', 'samples/0009_1_11.png', 'samples/0009_1_12.png', 'samples/0009_1_13.png', 'samples/0009_1_14.png', 'samples/0009_1_15.png', 'samples/0009_1_2.png', 'samples/0009_1_3.png', 'samples/0009_1_4.png', 'samples/0009_1_5.png', 'samples/0009_1_6.png', 'samples/0009_1_7.png', 'samples/0009_1_8.png', 'samples/0009_1_9.png']. This may take a bit of time if the files are large.
# WARNING:huggingface_hub.repository:Adding files tracked by Git LFS: ['samples/0009_1_0.png', 'samples/0009_1_1.png', 'samples/0009_1_10.png', 'samples/0009_1_11.png', 'samples/0009_1_12.png', 'samples/0009_1_13.png', 'samples/0009_1_14.png', 'samples/0009_1_15.png', 'samples/0009_1_2.png', 'samples/0009_1_3.png', 'samples/0009_1_4.png', 'samples/0009_1_5.png', 'samples/0009_1_6.png', 'samples/0009_1_7.png', 'samples/0009_1_8.png', 'samples/0009_1_9.png']. This may take a bit of time if the files are large.
# Upload file unet/diffusion_pytorch_model.bin:   0%|          | 3.34k/434M [00:00<?, ?B/s]
# Upload file samples/0009_1_0.png:   8%|8         | 3.34k/41.2k [00:00<?, ?B/s]
# Upload file samples/0009_1_13.png:   8%|7         | 3.34k/42.4k [00:00<?, ?B/s]
# Upload file samples/0009_1_12.png:   8%|8         | 3.34k/41.3k [00:00<?, ?B/s]
# Upload file logs/train_example/events.out.tfevents.1669435726.891e658791aa.79.0:   3%|3         | 3.34k/106k […
# Upload file samples/0009_1_4.png:   8%|7         | 3.34k/42.6k [00:00<?, ?B/s]
# Upload file samples/0009_1_10.png:   8%|7         | 3.34k/42.1k [00:00<?, ?B/s]
# Upload file samples/0009_1_3.png:   8%|8         | 3.34k/41.0k [00:00<?, ?B/s]
# Upload file samples/0009_1_1.png:   8%|8         | 3.34k/41.0k [00:00<?, ?B/s]
# Upload file samples/0009_1_9.png:   8%|8         | 3.34k/40.8k [00:00<?, ?B/s]
# Upload file samples/0009_1_14.png:   8%|8         | 3.34k/40.6k [00:00<?, ?B/s]
# Upload file samples/0009_1_8.png:   8%|8         | 3.34k/40.2k [00:00<?, ?B/s]
# Upload file samples/0009_1_2.png:   8%|8         | 3.34k/40.0k [00:00<?, ?B/s]
# Upload file samples/0009_1_15.png:   8%|8         | 3.34k/40.0k [00:00<?, ?B/s]
# Upload file samples/0009_1_6.png:   8%|8         | 3.34k/39.7k [00:00<?, ?B/s]
# Upload file samples/0009_1_5.png:   9%|8         | 3.34k/39.1k [00:00<?, ?B/s]
# Upload file samples/0009_1_11.png:   9%|8         | 3.34k/38.8k [00:00<?, ?B/s]
# Upload file samples/0009_1_7.png:   9%|8         | 3.34k/38.6k [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/emendes3/cancer_diffusion_model_pituitary_new
#    97b1785..876b839  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/emendes3/cancer_diffusion_model_pituitary_new
#    97b1785..876b839  main -> main
#
# To https://huggingface.co/emendes3/cancer_diffusion_model_pituitary_new
#    876b839..f20eacf  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/emendes3/cancer_diffusion_model_pituitary_new
#    876b839..f20eacf  main -> main
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Adding files tracked by Git LFS: ['samples/0019_1_0.png', 'samples/0019_1_1.png', 'samples/0019_1_10.png', 'samples/0019_1_11.png', 'samples/0019_1_12.png', 'samples/0019_1_13.png', 'samples/0019_1_14.png', 'samples/0019_1_15.png', 'samples/0019_1_2.png', 'samples/0019_1_3.png', 'samples/0019_1_4.png', 'samples/0019_1_5.png', 'samples/0019_1_6.png', 'samples/0019_1_7.png', 'samples/0019_1_8.png', 'samples/0019_1_9.png']. This may take a bit of time if the files are large.
# WARNING:huggingface_hub.repository:Adding files tracked by Git LFS: ['samples/0019_1_0.png', 'samples/0019_1_1.png', 'samples/0019_1_10.png', 'samples/0019_1_11.png', 'samples/0019_1_12.png', 'samples/0019_1_13.png', 'samples/0019_1_14.png', 'samples/0019_1_15.png', 'samples/0019_1_2.png', 'samples/0019_1_3.png', 'samples/0019_1_4.png', 'samples/0019_1_5.png', 'samples/0019_1_6.png', 'samples/0019_1_7.png', 'samples/0019_1_8.png', 'samples/0019_1_9.png']. This may take a bit of time if the files are large.
# Upload file unet/diffusion_pytorch_model.bin:   0%|          | 3.34k/434M [00:00<?, ?B/s]
# Upload file samples/0019_1_1.png:   8%|8         | 3.34k/41.4k [00:00<?, ?B/s]
# Upload file logs/train_example/events.out.tfevents.1669435726.891e658791aa.79.0:   2%|1         | 3.34k/213k […
# Upload file samples/0019_1_0.png:   7%|7         | 3.34k/45.4k [00:00<?, ?B/s]
# Upload file samples/0019_1_14.png:   8%|8         | 3.34k/41.2k [00:00<?, ?B/s]
# Upload file samples/0019_1_4.png:   8%|8         | 3.34k/40.7k [00:00<?, ?B/s]
# Upload file samples/0019_1_2.png:   8%|8         | 3.34k/41.0k [00:00<?, ?B/s]
# Upload file samples/0019_1_3.png:   8%|7         | 3.34k/43.4k [00:00<?, ?B/s]
# Upload file samples/0019_1_13.png:   8%|8         | 3.34k/40.6k [00:00<?, ?B/s]
# Upload file samples/0019_1_12.png:   8%|8         | 3.34k/40.5k [00:00<?, ?B/s]
# Upload file samples/0019_1_8.png:   8%|8         | 3.34k/40.0k [00:00<?, ?B/s]
# Upload file samples/0019_1_15.png:   8%|8         | 3.34k/40.0k [00:00<?, ?B/s]
# Upload file samples/0019_1_10.png:   8%|8         | 3.34k/39.8k [00:00<?, ?B/s]
# Upload file samples/0019_1_9.png:   8%|8         | 3.34k/39.7k [00:00<?, ?B/s]
# Upload file samples/0019_1_11.png:   9%|8         | 3.34k/39.1k [00:00<?, ?B/s]
# Upload file samples/0019_1_5.png:   9%|8         | 3.34k/38.6k [00:00<?, ?B/s]
# Upload file samples/0019_1_6.png:   9%|8         | 3.34k/37.8k [00:00<?, ?B/s]
# Upload file samples/0019_1_7.png:   9%|8         | 3.34k/37.4k [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/emendes3/cancer_diffusion_model_pituitary_new
#    f20eacf..8dcb403  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/emendes3/cancer_diffusion_model_pituitary_new
#    f20eacf..8dcb403  main -> main
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Adding files tracked by Git LFS: ['samples/0029_1_0.png', 'samples/0029_1_1.png', 'samples/0029_1_10.png', 'samples/0029_1_11.png', 'samples/0029_1_12.png', 'samples/0029_1_13.png', 'samples/0029_1_14.png', 'samples/0029_1_15.png', 'samples/0029_1_2.png', 'samples/0029_1_3.png', 'samples/0029_1_4.png', 'samples/0029_1_5.png', 'samples/0029_1_6.png', 'samples/0029_1_7.png', 'samples/0029_1_8.png', 'samples/0029_1_9.png']. This may take a bit of time if the files are large.
# WARNING:huggingface_hub.repository:Adding files tracked by Git LFS: ['samples/0029_1_0.png', 'samples/0029_1_1.png', 'samples/0029_1_10.png', 'samples/0029_1_11.png', 'samples/0029_1_12.png', 'samples/0029_1_13.png', 'samples/0029_1_14.png', 'samples/0029_1_15.png', 'samples/0029_1_2.png', 'samples/0029_1_3.png', 'samples/0029_1_4.png', 'samples/0029_1_5.png', 'samples/0029_1_6.png', 'samples/0029_1_7.png', 'samples/0029_1_8.png', 'samples/0029_1_9.png']. This may take a bit of time if the files are large.
# Upload file unet/diffusion_pytorch_model.bin:   0%|          | 3.34k/434M [00:00<?, ?B/s]
# Upload file samples/0029_1_14.png:   9%|8         | 3.34k/38.3k [00:00<?, ?B/s]
# Upload file samples/0029_1_0.png:   8%|8         | 3.34k/41.3k [00:00<?, ?B/s]
# Upload file samples/0029_1_1.png:   9%|8         | 3.34k/38.0k [00:00<?, ?B/s]
# Upload file logs/train_example/events.out.tfevents.1669435726.891e658791aa.79.0:   1%|1         | 3.34k/320k […
# Upload file samples/0029_1_3.png:   8%|8         | 3.34k/40.7k [00:00<?, ?B/s]
# Upload file samples/0029_1_2.png:   9%|8         | 3.34k/37.3k [00:00<?, ?B/s]
# Upload file samples/0029_1_13.png:   9%|8         | 3.34k/38.1k [00:00<?, ?B/s]
# Upload file samples/0029_1_4.png:   9%|8         | 3.34k/37.2k [00:00<?, ?B/s]
# Upload file samples/0029_1_12.png:   9%|9         | 3.34k/36.9k [00:00<?, ?B/s]
# Upload file samples/0029_1_15.png:   9%|9         | 3.34k/36.7k [00:00<?, ?B/s]
# Upload file samples/0029_1_8.png:   9%|9         | 3.34k/36.6k [00:00<?, ?B/s]
# Upload file samples/0029_1_10.png:   9%|9         | 3.34k/36.5k [00:00<?, ?B/s]
# Upload file samples/0029_1_9.png:   9%|9         | 3.34k/36.4k [00:00<?, ?B/s]
# Upload file samples/0029_1_7.png:   9%|9         | 3.34k/36.3k [00:00<?, ?B/s]
# Upload file samples/0029_1_11.png:   9%|9         | 3.34k/36.2k [00:00<?, ?B/s]
# Upload file samples/0029_1_5.png:   9%|9         | 3.34k/36.0k [00:00<?, ?B/s]
# Upload file samples/0029_1_6.png:  10%|9         | 3.34k/35.1k [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/emendes3/cancer_diffusion_model_pituitary_new
#    8dcb403..315e2fe  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/emendes3/cancer_diffusion_model_pituitary_new
#    8dcb403..315e2fe  main -> main
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Adding files tracked by Git LFS: ['samples/0039_1_0.png', 'samples/0039_1_1.png', 'samples/0039_1_10.png', 'samples/0039_1_11.png', 'samples/0039_1_12.png', 'samples/0039_1_13.png', 'samples/0039_1_14.png', 'samples/0039_1_15.png', 'samples/0039_1_2.png', 'samples/0039_1_3.png', 'samples/0039_1_4.png', 'samples/0039_1_5.png', 'samples/0039_1_6.png', 'samples/0039_1_7.png', 'samples/0039_1_8.png', 'samples/0039_1_9.png']. This may take a bit of time if the files are large.
# WARNING:huggingface_hub.repository:Adding files tracked by Git LFS: ['samples/0039_1_0.png', 'samples/0039_1_1.png', 'samples/0039_1_10.png', 'samples/0039_1_11.png', 'samples/0039_1_12.png', 'samples/0039_1_13.png', 'samples/0039_1_14.png', 'samples/0039_1_15.png', 'samples/0039_1_2.png', 'samples/0039_1_3.png', 'samples/0039_1_4.png', 'samples/0039_1_5.png', 'samples/0039_1_6.png', 'samples/0039_1_7.png', 'samples/0039_1_8.png', 'samples/0039_1_9.png']. This may take a bit of time if the files are large.
# Upload file unet/diffusion_pytorch_model.bin:   0%|          | 3.34k/434M [00:00<?, ?B/s]
# Upload file samples/0039_1_3.png:   9%|8         | 3.34k/39.3k [00:00<?, ?B/s]
# Upload file samples/0039_1_12.png:   9%|9         | 3.34k/36.2k [00:00<?, ?B/s]
# Upload file samples/0039_1_10.png:   9%|9         | 3.34k/35.8k [00:00<?, ?B/s]
# Upload file samples/0039_1_0.png:   9%|8         | 3.34k/37.9k [00:00<?, ?B/s]
# Upload file samples/0039_1_4.png:   9%|9         | 3.34k/36.4k [00:00<?, ?B/s]
# Upload file logs/train_example/events.out.tfevents.1669435726.891e658791aa.79.0:   1%|          | 3.34k/426k […
# Upload file samples/0039_1_1.png:   9%|9         | 3.34k/35.8k [00:00<?, ?B/s]
# Upload file samples/0039_1_13.png:   9%|9         | 3.34k/35.8k [00:00<?, ?B/s]
# Upload file samples/0039_1_14.png:   9%|9         | 3.34k/35.8k [00:00<?, ?B/s]
# Upload file samples/0039_1_2.png:   9%|9         | 3.34k/35.2k [00:00<?, ?B/s]
# Upload file samples/0039_1_9.png:  10%|9         | 3.34k/34.3k [00:00<?, ?B/s]
# Upload file samples/0039_1_8.png:  10%|9         | 3.34k/34.1k [00:00<?, ?B/s]
# Upload file samples/0039_1_15.png:  10%|9         | 3.34k/34.0k [00:00<?, ?B/s]
# Upload file samples/0039_1_11.png:  10%|#         | 3.34k/32.7k [00:00<?, ?B/s]
# Upload file samples/0039_1_5.png:  10%|#         | 3.34k/32.5k [00:00<?, ?B/s]
# Upload file samples/0039_1_7.png:  11%|#         | 3.34k/31.6k [00:00<?, ?B/s]
# Upload file samples/0039_1_6.png:  11%|#         | 3.34k/31.4k [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/emendes3/cancer_diffusion_model_pituitary_new
#    315e2fe..ae78336  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/emendes3/cancer_diffusion_model_pituitary_new
#    315e2fe..ae78336  main -> main
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Adding files tracked by Git LFS: ['samples/0049_1_0.png', 'samples/0049_1_1.png', 'samples/0049_1_10.png', 'samples/0049_1_11.png', 'samples/0049_1_12.png', 'samples/0049_1_13.png', 'samples/0049_1_14.png', 'samples/0049_1_15.png', 'samples/0049_1_2.png', 'samples/0049_1_3.png', 'samples/0049_1_4.png', 'samples/0049_1_5.png', 'samples/0049_1_6.png', 'samples/0049_1_7.png', 'samples/0049_1_8.png', 'samples/0049_1_9.png']. This may take a bit of time if the files are large.
# WARNING:huggingface_hub.repository:Adding files tracked by Git LFS: ['samples/0049_1_0.png', 'samples/0049_1_1.png', 'samples/0049_1_10.png', 'samples/0049_1_11.png', 'samples/0049_1_12.png', 'samples/0049_1_13.png', 'samples/0049_1_14.png', 'samples/0049_1_15.png', 'samples/0049_1_2.png', 'samples/0049_1_3.png', 'samples/0049_1_4.png', 'samples/0049_1_5.png', 'samples/0049_1_6.png', 'samples/0049_1_7.png', 'samples/0049_1_8.png', 'samples/0049_1_9.png']. This may take a bit of time if the files are large.
# Upload file unet/diffusion_pytorch_model.bin:   0%|          | 3.34k/434M [00:00<?, ?B/s]
# Upload file logs/train_example/events.out.tfevents.1669435726.891e658791aa.79.0:   1%|          | 3.34k/533k […
# Upload file samples/0049_1_1.png:  10%|9         | 3.34k/35.0k [00:00<?, ?B/s]
# Upload file samples/0049_1_3.png:   9%|8         | 3.34k/37.8k [00:00<?, ?B/s]
# Upload file samples/0049_1_0.png:   9%|8         | 3.34k/37.4k [00:00<?, ?B/s]
# Upload file samples/0049_1_12.png:   9%|9         | 3.34k/35.5k [00:00<?, ?B/s]
# Upload file samples/0049_1_4.png:   9%|9         | 3.34k/37.0k [00:00<?, ?B/s]
# Upload file samples/0049_1_10.png:   9%|9         | 3.34k/35.2k [00:00<?, ?B/s]
# Upload file samples/0049_1_13.png:  10%|9         | 3.34k/34.7k [00:00<?, ?B/s]
# Upload file samples/0049_1_14.png:  10%|9         | 3.34k/34.7k [00:00<?, ?B/s]
# Upload file samples/0049_1_2.png:  10%|9         | 3.34k/34.4k [00:00<?, ?B/s]
# Upload file samples/0049_1_8.png:  10%|#         | 3.34k/32.9k [00:00<?, ?B/s]
# Upload file samples/0049_1_15.png:  10%|#         | 3.34k/32.7k [00:00<?, ?B/s]
# Upload file samples/0049_1_9.png:  10%|#         | 3.34k/32.6k [00:00<?, ?B/s]
# Upload file samples/0049_1_5.png:  11%|#         | 3.34k/31.5k [00:00<?, ?B/s]
# Upload file samples/0049_1_11.png:  11%|#         | 3.34k/31.0k [00:00<?, ?B/s]
# Upload file samples/0049_1_7.png:  11%|#         | 3.34k/30.6k [00:00<?, ?B/s]
# Upload file samples/0049_1_6.png:  11%|#1        | 3.34k/29.4k [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/emendes3/cancer_diffusion_model_pituitary_new
#    ae78336..9fde7ae  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/emendes3/cancer_diffusion_model_pituitary_new
#    ae78336..9fde7ae  main -> main

# %%
accelerator = Accelerator(
    mixed_precision=config.mixed_precision,
    gradient_accumulation_steps=config.gradient_accumulation_steps, 
    log_with="tensorboard",
    logging_dir=os.path.join(config.output_dir, "logs")
)
pipeline = DDPMPipeline(unet=accelerator.unwrap_model(model), scheduler=noise_scheduler)
for i in range (2, 10):
  get_images(config, 30, i, pipeline)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
# !zip -r /content/images_10.zip f'/content/cancer_diffusion_model_{class_name}/samples'

# %%
from google.colab import files
files.download("/content/images_10.zip")

# %%
accelerator = Accelerator(
    mixed_precision=config.mixed_precision,
    gradient_accumulation_steps=config.gradient_accumulation_steps, 
    log_with="tensorboard",
    logging_dir=os.path.join(config.output_dir, "logs")
)
pipeline = DDPMPipeline(unet=accelerator.unwrap_model(model), scheduler=noise_scheduler)
for i in range (11, 19):
  get_images(config, 30, i, pipeline)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-beb5b7de2827> in <module>()
#       7 pipeline = DDPMPipeline(unet=accelerator.unwrap_model(model), scheduler=noise_scheduler)
#       8 for i in range (11, 19):
# ----> 9   get_images(config, 30, i, pipeline)
#
# <ipython-input-42-a00d0f7b9df1> in get_images(config, epoch, batch, pipeline)
#      31     images = pipeline(
#      32         batch_size = 16,
# ---> 33         generator=batch,
#      34     ).images
#      35
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /usr/local/lib/python3.7/dist-packages/diffusers/pipelines/ddpm/pipeline_ddpm.py in __call__(self, batch_size, generator, output_type, return_dict, **kwargs)
#      69         image = torch.randn(
#      70             (batch_size, self.unet.in_channels, self.unet.sample_size, self.unet.sample_size),
# ---> 71             generator=generator,
#      72         )
#      73         image = image.to(self.device)
#
# TypeError: randn() received an invalid combination of arguments - got (tuple, generator=int), but expected one of:
#  * (tuple of ints size, *, torch.Generator generator, tuple of names names, torch.dtype dtype, torch.layout layout, torch.device device, bool pin_memory, bool requires_grad)
#  * (tuple of ints size, *, torch.Generator generator, Tensor out, torch.dtype dtype, torch.layout layout, torch.device device, bool pin_memory, bool requires_grad)
#  * (tuple of ints size, *, Tensor out, torch.dtype dtype, torch.layout layout, torch.device device, bool pin_memory, bool requires_grad)
#  * (tuple of ints size, *, tuple of names names, torch.dtype dtype, torch.layout layout, torch.device device, bool pin_memory, bool requires_grad)

# %%
# !zip -r /content/images_19.zip f'/content/cancer_diffusion_model_{class_name}/samples'

# %%
from google.colab import files
files.download("/content/images_19.zip")

# %%
accelerator = Accelerator(
    mixed_precision=config.mixed_precision,
    gradient_accumulation_steps=config.gradient_accumulation_steps, 
    log_with="tensorboard",
    logging_dir=os.path.join(config.output_dir, "logs")
)
pipeline = DDPMPipeline(unet=accelerator.unwrap_model(model), scheduler=noise_scheduler)
for i in range (30, 43):
  get_images(config, 30, i, pipeline)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
print(i)
# Out:
# 24

# %%
# !zip -r /content/images_43.zip f'/content/cancer_diffusion_model_{class_name}/samples'

# %%
from google.colab import files
files.download("/content/images_43.zip")

# %%
len(os.listdir("/content/cancer_diffusion_model_pituitary/samples"))
# Out:
# 471

# %% [markdown]
# Let's have a look at the final image grid produced by the trained diffusion model:

# %% [markdown]
# Not bad! There's room for improvement of course, so feel free to play with the hyperparameters, model definition and image augmentations 🤗
#
# If you've chosen to upload the model to the Hugging Face Hub, its repository should now look like so:
# https://huggingface.co/anton-l/ddpm-butterflies-128
#
# If you want to dive deeper into the code, we also have more advanced training scripts with features like Exponential Moving Average of model weights here:
#
# https://github.com/huggingface/diffusers/tree/main/examples
