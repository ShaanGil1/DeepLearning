# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
cd '/content/drive/.shortcut-targets-by-id/1wi9vgavoChaiKzvd4yqdbBeMVY8Gujox/DL Project/diffusion_images/diffusion_1008.zip'
# Out:
# /content/drive/.shortcut-targets-by-id/1wi9vgavoChaiKzvd4yqdbBeMVY8Gujox/DL Project

# %%
# !unzip '/content/drive/.shortcut-targets-by-id/1wi9vgavoChaiKzvd4yqdbBeMVY8Gujox/DL Project/diffusion_images/diffusion_1008.zip' -d ./diffusion_images

# %%
# !unzip '/content/drive/.shortcut-targets-by-id/1wi9vgavoChaiKzvd4yqdbBeMVY8Gujox/DL Project/skewed_shrunk_bw.zip' -d ./original_images

# %%
import matplotlib.pyplot as plt
import os
import matplotlib.image as mpimg
import numpy as np

glioma = os.listdir("diffusion_images/glioma")[51:55]
meningioma = os.listdir("diffusion_images/meningioma")[0:4]
pituitary = os.listdir("diffusion_images/pituitary")[0:4]

plt.figure(figsize=(5,10))
columns = 3
glioma_base = os.listdir("original_images/skewed/data/Training/glioma")[0]
meningioma_base = os.listdir("original_images/skewed/data/Training/meningioma")[0]
pituitary_base = os.listdir("original_images/skewed/data/Training/pituitary")[0]

glioma_image = mpimg.imread(os.path.join("original_images/skewed/data/Training/glioma", glioma_base))
meningioma_image = mpimg.imread(os.path.join("original_images/skewed/data/Training/meningioma", meningioma_base))
pituitary_image = mpimg.imread(os.path.join("original_images/skewed/data/Training/pituitary", pituitary_base))

plt.gray()
ax = plt.subplot(15 / columns + 1, columns, 1)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.imshow(glioma_image)
ax = plt.subplot(15 / columns + 1, columns, 2)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.imshow(meningioma_image)
ax = plt.subplot(15 / columns + 1, columns, 3)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.imshow(pituitary_image)

for i in range(4): 
    glioma_image = mpimg.imread(os.path.join("diffusion_images/glioma", glioma[i]))
    meningioma_image = mpimg.imread(os.path.join("diffusion_images/meningioma", meningioma[i]))
    pituitary_image = mpimg.imread(os.path.join("diffusion_images/pituitary", pituitary[i]))

    ax = plt.subplot(15 / columns + 1, columns, 3 * i + 4)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    plt.imshow(glioma_image)
    ax = plt.subplot(15 / columns + 1, columns, 3 * i + 5)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    plt.imshow(meningioma_image)
    ax = plt.subplot(15 / columns + 1, columns, 3 * i + 6)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    plt.imshow(pituitary_image)
'''
for i, image_file in enumerate(images):
    image = mpimg.imread(os.path.join("diffusion_images/diffusion_samples", image_file))
    ax = plt.subplot(len(images) / columns + 1, columns, i + 1)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    plt.imshow(image)
'''
# Out:
# '\nfor i, image_file in enumerate(images):\n    image = mpimg.imread(os.path.join("diffusion_images/diffusion_samples", image_file))\n    ax = plt.subplot(len(images) / columns + 1, columns, i + 1)\n    ax.get_xaxis().set_visible(False)\n    ax.get_yaxis().set_visible(False)\n    plt.imshow(image)\n'
